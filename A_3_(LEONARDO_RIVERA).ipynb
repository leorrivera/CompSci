# %% [markdown]
# <a href="https://colab.research.google.com/github/leorrivera/CompSci/blob/main/A_3_(LEONARDO_RIVERA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem-1
#
# Types of Functions
#
# Below are the 4-different versions of functions. It is always safe to assume that if return type is not given, it defaults to no return type for that function. Write functions and their invocations (function calls) in main function to invoke the functions code.
#
# Write a function avg_num that take two parameters, calculate their average and return average.
# Write a function print_str that take one parameter, and print that parameter.
# Write a function my_num that takes no parameters, and returns your favorite number.
# Write a function hello_msg that takes no parameters, and prints "hello world".

# %%
# Comments
def avg_num(x, y):
    avg = (x + y) / 2
    return avg

# Comments
def print_str(strng):
    print(strng)

# Comments
def my_num():
    fav_num = 20
    return fav_num

# Comments
def hello_msg():
    print("hello world")

# %% [markdown]
# Create a function exp_growth that take three inputs (A, k, and t) and calculates and returns the estimated population (P) of a country using the exponential growth/decay model. Use the following formula:
#
# ![image.png](data:image/png;base64,...)
#
# P = the population after exponential growth has been applied
#
# A = the initial population
#
# e = Euler’s Number (Use 2.7 in your program to estimate this number)
#
# k = growth rate
#
# t = time in years

# %%
# Comments
def exp_growth(A, k, t):
  import math
  e = 2.7
  P = A * math.pow(e, k * t)
  return P

# %% [markdown]
# Create a function point_distance that take four inputs (x1, y1, x2, and y2) and calculates and returns the distance (d) between two points using the distance formula. Use the following formula:
#
# ![image.png](data:image/png;base64,...)
#
# d = the distance between the two points
#
# x1, y1 = first (x, y) coordinates
#
# x2, y2 = second (x, y) coordinates

# %%
# Comments
def point_distance(x1, y1, x2, y2):
  import math
  d = math.sqrt((x1-x2)**2 + (y1-y2)**2)
  return d

# %% [markdown]
# Create a function slope that take four inputs (x1, y1, x2, and y2) and calculates and returns the slope (m) between the two points. Use the following formula:
#
# ![image.png](data:image/png;base64,...)
#
# m = the slope between the two points
#
# x1, y1 = first (x, y) coordinates
#
# x2, y2 = second (x, y) coordinates

# %%
# Comments
def slope(x1, y1, x2, y2):
  m = (y2 - y2) / (x2-x1)
  return m

# %%
# Comments
def fn():
    pass

def main():
  ### Your Code Goes Here -- starting with indentation (lines up)
  x = 5
  y = 10
  avg = avg_num(x, y)
  print("avg", avg)
  print_str("hello")
  fav_num = 20
  print("20")
  print("hello word")
  e = 2.7
  A = 10000
  k = 0.10
  t = 10
  import math
  P = A * math.pow(e, k * t)
  print(f"P : {P: .2f}")
  x1 = 2
  x2 = 4
  y1 = 3
  y2 = 6
  import math
  d = math.sqrt((x1-x2)**2 + (y1-y2)**2)
  print(f'd: {d: .2f}' )
  x1,y1 = 3, 4
  x2, y2 = 6, 5
  m = (y2 - y1) / (x2-x1)
  print (f'm : {m: .2f}')
  pass

if __name__ == '__main__':
    main()
# Out:
# avg 7.5
# hello
# 20
# hello word
# P :  27000.00
# d:  3.61
# m :  0.33
